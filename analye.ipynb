# %%
import json
import re

# %%
with open('./metrics.json') as jsonFile:
  data = json.load(jsonFile)
# Out:
# {'service': [{'name': 'actions',
#    'launchStates': 'Metrics from Google Assistant Smart Home. Launch stages of these metrics: ALPHA BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with actions.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 0},
#   {'name': 'aiplatform',
#    'launchStates': 'Metrics from Vertex AI. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with aiplatform.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 1},
#   {'name': 'alloydb',
#    'launchStates': 'Metrics from AlloyDB for PostgreSQL. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with alloydb.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 2},
#   {'name': 'apigateway',
#    'launchStates': 'Metrics from API Gateway. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with apigateway.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 3},
#   {'name': 'apigee',
#    'launchStates': 'Metrics from Apigee. Launch stages of these metrics: ALPHA BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with apigee.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 4},
#   {'name': 'appengine',
#    'launchStates': 'Metrics from App Engine. Note: If you use App Engine flexible environment in combination with Cloud Load Balancing, then certain metrics in the following table are reported as metrics from the loadbalancing table instead. For more information, see External HTTP(S) load balancer logging and monitoring. Launch stages of these metrics: ALPHA BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with appengine.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 5},
#   {'name': 'autoscaler',
#    'launchStates': 'Metrics from Compute Engine Autoscaler. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with autoscaler.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 6},
#   {'name': 'baremetalsolution',
#    'launchStates': 'Metrics from Bare Metal Solution Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with baremetalsolution.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 7},
#   {'name': 'GA',
#    'launchStates': '',
#    'description': 'The "metric type" strings in this table must be prefixed with bigquery.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 8},
#   {'name': 'bigquerybiengine',
#    'launchStates': 'Metrics from BigQuery BI Engine. Launch stages of these metrics: GA',
#    'description': 'The "metric type" strings in this table must be prefixed with bigquerybiengine.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 9},
#   {'name': 'bigquerydatatransfer',
#    'launchStates': 'Metrics from the BigQuery Data Transfer Service. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with bigquerydatatransfer.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 10},
#   {'name': 'bigquerystorage',
#    'launchStates': 'Metrics from the BigQuery Storage API. Launch stages of these metrics: ALPHA BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with bigquerystorage.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 11},
#   {'name': 'bigtable',
#    'launchStates': 'Metrics from Cloud Bigtable. Launch stages of these metrics: EARLY_ACCESS GA',
#    'description': 'The "metric type" strings in this table must be prefixed with bigtable.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 12},
#   {'name': 'certificatemanager',
#    'launchStates': 'Metrics from Certificate Manager. Launch stages of these metrics: GA',
#    'description': 'The "metric type" strings in this table must be prefixed with certificatemanager.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 13},
#   {'name': 'clouddeploy',
#    'launchStates': 'Metrics from Google Cloud Deploy. Launch stages of these metrics: GA',
#    'description': 'The "metric type" strings in this table must be prefixed with clouddeploy.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 14},
#   {'name': 'cloudfunctions',
#    'launchStates': 'Metrics from Cloud Functions. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with cloudfunctions.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 15},
#   {'name': 'cloudiot',
#    'launchStates': 'Metrics from IoT Core. Launch stages of these metrics: GA',
#    'description': 'The "metric type" strings in this table must be prefixed with cloudiot.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 16},
#   {'name': 'cloudkms',
#    'launchStates': 'Metrics from Cloud Key Management Service. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with cloudkms.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 17},
#   {'name': 'cloudsql',
#    'launchStates': 'Metrics from Cloud SQL. Launch stages of these metrics: ALPHA BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with cloudsql.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 18},
#   {'name': 'GA',
#    'launchStates': '',
#    'description': 'The "metric type" strings in this table must be prefixed with cloudtasks.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 19},
#   {'name': 'cloudtrace',
#    'launchStates': 'Metrics from Cloud Trace. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with cloudtrace.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 20},
#   {'name': 'composer',
#    'launchStates': 'Metrics from Cloud Composer. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with composer.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 21},
#   {'name': 'GA',
#    'launchStates': '',
#    'description': 'The "metric type" strings in this table must be prefixed with compute.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 22},
#   {'name': 'contactcenterinsights',
#    'launchStates': 'Metrics from Contact Center AI Insights. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with contactcenterinsights.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 23},
#   {'name': 'container',
#    'launchStates': 'Metrics from Google Kubernetes Engine. For newer Kubernetes metrics, see the kubernetes.io metrics.',
#    'description': 'The "metric type" strings in this table must be prefixed with container.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 24},
#   {'name': 'dataflow',
#    'launchStates': 'Metrics from Dataflow. For more information about Dataflow monitoring, see Monitoring Dataflow pipelines and Dataflow monitoring interface. Launch stages of these metrics: ALPHA BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with dataflow.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 25},
#   {'name': 'datamigration',
#    'launchStates': 'Metrics from Database Migration. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with datamigration.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 26},
#   {'name': 'dataplex',
#    'launchStates': 'Metrics from Dataplex. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with dataplex.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 27},
#   {'name': 'dataproc',
#    'launchStates': 'Metrics from Dataproc. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with dataproc.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 28},
#   {'name': 'datastore',
#    'launchStates': 'Metrics from Datastore. Launch stages of these metrics: GA',
#    'description': 'The "metric type" strings in this table must be prefixed with datastore.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 29},
#   {'name': 'datastream',
#    'launchStates': 'Metrics from Datastream. Launch stages of these metrics: ALPHA BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with datastream.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 30},
#   {'name': 'dbinsights',
#    'launchStates': 'Metrics from Cloud SQL for MySQL. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with dbinsights.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 31},
#   {'name': 'dlp',
#    'launchStates': 'Metrics from Cloud Data Loss Prevention. Launch stages of these metrics: ALPHA BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with dlp.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 32},
#   {'name': 'dns',
#    'launchStates': 'Metrics from Cloud DNS. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with dns.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 33},
#   {'name': 'earthengine',
#    'launchStates': 'Metrics from Earth Engine. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with earthengine.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 34},
#   {'name': 'edgecache',
#    'launchStates': 'Metrics from Media CDN. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with edgecache.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 35},
#   {'name': 'edgecontainer',
#    'launchStates': 'Metrics from Edge Container. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with edgecontainer.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 36},
#   {'name': 'file',
#    'launchStates': 'Metrics from Filestore. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with file.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 37},
#   {'name': 'firebaseappcheck',
#    'launchStates': 'Metrics from Firebase. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with firebaseappcheck.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 38},
#   {'name': 'firebasedatabase',
#    'launchStates': 'Metrics from Firebase. Launch stages of these metrics: GA',
#    'description': 'The "metric type" strings in this table must be prefixed with firebasedatabase.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 39},
#   {'name': 'firebaseextensions',
#    'launchStates': 'Metrics from Firebase. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with firebaseextensions.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 40},
#   {'name': 'firebasehosting',
#    'launchStates': 'Metrics from Firebase. Launch stages of these metrics: GA',
#    'description': 'The "metric type" strings in this table must be prefixed with firebasehosting.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 41},
#   {'name': 'firebasestorage',
#    'launchStates': 'Metrics from Cloud Storage for Firebase. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with firebasestorage.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 42},
#   {'name': 'firestore',
#    'launchStates': 'Metrics from Firestore. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with firestore.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 43},
#   {'name': 'firewallinsights',
#    'launchStates': 'Metrics from Firewall Insights. Launch stages of these metrics: GA',
#    'description': 'The "metric type" strings in this table must be prefixed with firewallinsights.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 44},
#   {'name': 'fleetengine',
#    'launchStates': 'Metrics from Fleet Engine. Launch stages of these metrics: GA',
#    'description': 'The "metric type" strings in this table must be prefixed with fleetengine.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 45},
#   {'name': 'gkebackup',
#    'launchStates': 'Metrics from Backup for GKE. Launch stages of these metrics: GA',
#    'description': 'The "metric type" strings in this table must be prefixed with gkebackup.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 46},
#   {'name': 'healthcare',
#    'launchStates': 'Metrics from Cloud Healthcare API. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with healthcare.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 47},
#   {'name': 'iam',
#    'launchStates': 'Metrics from Identity and Access Management. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with iam.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 48},
#   {'name': 'identitytoolkit',
#    'launchStates': 'Metrics from Identity Platform. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with identitytoolkit.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 49},
#   {'name': 'ids',
#    'launchStates': 'Metrics from Cloud IDS. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with ids.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 50},
#   {'name': 'interconnect',
#    'launchStates': 'Metrics from Cloud Interconnect. For Dedicated Interconnect, Monitoring and Google Cloud collect measurements for the network/interconnect and network/attachment metric types. For Partner Interconnect, Monitoring and Google Cloud collect measurements for the network/attachment metric type only. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with interconnect.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 51},
#   {'name': 'livestream',
#    'launchStates': 'Metrics for Live Stream API. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with livestream.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 52},
#   {'name': 'loadbalancing',
#    'launchStates': 'Metrics for Cloud Load Balancing. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with loadbalancing.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 53},
#   {'name': 'logging',
#    'launchStates': 'Metrics from Cloud Logging. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with logging.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 54},
#   {'name': 'managedidentities',
#    'launchStates': 'Metrics from Managed Service for Microsoft Active Directory. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with managedidentities.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 55},
#   {'name': 'maps',
#    'launchStates': 'Metrics from Google Maps Platform. Launch stages of these metrics: GA',
#    'description': 'The "metric type" strings in this table must be prefixed with maps.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 56},
#   {'name': 'memcache',
#    'launchStates': 'Metrics from Memorystore for Memcached. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with memcache.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 57},
#   {'name': 'metastore',
#    'launchStates': 'Metrics from Dataproc Metastore. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with metastore.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 58},
#   {'name': 'ml',
#    'launchStates': 'Metrics from AI Platform (formerly Cloud Machine Learning). Launch stages of these metrics: ALPHA BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with ml.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 59},
#   {'name': 'monitoring',
#    'launchStates': 'Metrics from Cloud Monitoring. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with monitoring.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 60},
#   {'name': 'networking',
#    'launchStates': 'Metrics from Network Topology. Launch stages of these metrics: ALPHA BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with networking.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 61},
#   {'name': 'networksecurity',
#    'launchStates': 'Metrics from Google Cloud Armor. Launch stages of these metrics: GA',
#    'description': 'The "metric type" strings in this table must be prefixed with networksecurity.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 62},
#   {'name': 'osconfig',
#    'launchStates': 'Metrics from VM Manager. Launch stages of these metrics: GA',
#    'description': 'The "metric type" strings in this table must be prefixed with osconfig.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 63},
#   {'name': 'privateca',
#    'launchStates': 'Metrics from Certificate Authority Service. Launch stages of these metrics: GA',
#    'description': 'The "metric type" strings in this table must be prefixed with privateca.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 64},
#   {'name': 'pubsub',
#    'launchStates': 'Metrics from Pub/Sub. For more information, see Pub/Sub monitoring. Launch stages of these metrics: ALPHA BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with pubsub.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 65},
#   {'name': 'pubsublite',
#    'launchStates': 'Metrics from Pub/Sub Lite. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with pubsublite.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 66},
#   {'name': 'recaptchaenterprise',
#    'launchStates': 'Metrics from reCAPTCHA Enterprise. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with recaptchaenterprise.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 67},
#   {'name': 'recommendationengine',
#    'launchStates': 'Metrics from Recommendations AI. Launch stages of these metrics: EARLY_ACCESS',
#    'description': 'The "metric type" strings in this table must be prefixed with recommendationengine.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 68},
#   {'name': 'redis',
#    'launchStates': 'Metrics from Memorystore for Redis. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with redis.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 69},
#   {'name': 'router',
#    'launchStates': 'Metrics from Cloud Router. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with router.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 70},
#   {'name': 'run',
#    'launchStates': 'Metrics from managed Cloud Run. (For Cloud Run for Anthos metrics, see Kubernetes metrics and Knative metrics.) Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with run.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 71},
#   {'name': 'serviceruntime',
#    'launchStates': 'Metrics available to all Google Cloud APIs (resource type consumed_api) and to your APIs created with Cloud Endpoints (resource type api). Not all APIs use serviceruntime metrics; for example, the Datastore API does not. The resources listed for the metrics are at launch stage GA, except for api, which is at launch stage BETA.',
#    'description': 'The "metric type" strings in this table must be prefixed with serviceruntime.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 72},
#   {'name': 'spanner',
#    'launchStates': 'Metrics from Cloud Spanner. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with spanner.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 73},
#   {'name': 'storage',
#    'launchStates': 'Metrics from Cloud Storage. Launch stages of these metrics: BETA GA',
#    'description': 'The "metric type" strings in this table must be prefixed with storage.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 74},
#   {'name': 'storagetransfer',
#    'launchStates': 'Metrics from Storage Transfer Service. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with storagetransfer.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 75},
#   {'name': 'tpu',
#    'launchStates': 'Metrics from Cloud TPU. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with tpu.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 76},
#   {'name': 'trafficdirector',
#    'launchStates': 'Metrics from Traffic Director. Launch stages of these metrics: GA',
#    'description': 'The "metric type" strings in this table must be prefixed with trafficdirector.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 77},
#   {'name': 'transferappliance',
#    'launchStates': 'Metrics from Transfer Appliance. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with transferappliance.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 78},
#   {'name': 'videostitcher',
#    'launchStates': 'Metrics from Video Stitcher API. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with videostitcher.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 79},
#   {'name': 'visionai',
#    'launchStates': 'Metrics from Vision AI. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with visionai.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 80},
#   {'name': 'vpc access',
#    'launchStates': 'Metrics from Virtual Private Cloud (VPC). Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with vpcaccess.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 81},
#   {'name': 'vpn',
#    'launchStates': 'Metrics from Cloud VPN. Launch stages of these metrics: GA',
#    'description': 'The "metric type" strings in this table must be prefixed with vpn.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 82},
#   {'name': 'workflows',
#    'launchStates': 'Metrics from Workflows. Launch stages of these metrics: BETA',
#    'description': 'The "metric type" strings in this table must be prefixed with workflows.googleapis.com/. That prefix has been omitted from the entries in the table.',
#    'serviceIndex': 83}],
#  'serviceMetrics': [{'metricInfo': {'name': 'smarthome_action/camerastream/first_frame_latencies',
#     'launchStatus': 'BETA',
#     'displayName': 'First frame latency'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'DISTRIBUTION',
#     'unit': 'milliseconds',
#     'monitoredResources': 'assistant_action_project',
#     'description': 'Latency for first frame to arrive. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['device_type :\n\n              Device type, one of [CAMERA, DOORBELL]',
#      'stream_status :\n\n              The canonical code that represents the result, for example, "COMPLETED" or "FAILED".',
#      'stream_protocol :\n\n              Underlying protocol used for camerastream, for example, "webrtc" or "hls".',
#      'is_battery_powered :\n\n                (BOOL)\n\n              Whether the device is battery powered or not.']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/camerastream/frame_display_rates',
#     'launchStatus': 'BETA',
#     'displayName': 'Frame display rate'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'DISTRIBUTION',
#     'unit': 'frames/seconds',
#     'monitoredResources': 'assistant_action_project',
#     'description': 'Rate at which camerastream frames are displayed. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['device_type :\n\n              Device type, one of [CAMERA, DOORBELL]',
#      'stream_status :\n\n              The canonical code that represents the result, for example, "COMPLETED" or "FAILED".',
#      'stream_protocol :\n\n              Underlying protocol used for camerastream, for example, "webrtc" or "hls".',
#      'is_battery_powered :\n\n                (BOOL)\n\n              Whether the device is battery powered or not.']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/camerastream/frame_drop_rates',
#     'launchStatus': 'BETA',
#     'displayName': 'Frame drop rate'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'DISTRIBUTION',
#     'unit': 'frames/seconds',
#     'monitoredResources': 'assistant_action_project',
#     'description': 'Rate at which camerastream frames are dropped. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['device_type :\n\n              Device type, one of [CAMERA, DOORBELL]',
#      'stream_status :\n\n              The canonical code that represents the result, for example, "COMPLETED" or "FAILED".',
#      'stream_protocol :\n\n              Underlying protocol used for camerastream, for example, "webrtc" or "hls".',
#      'is_battery_powered :\n\n                (BOOL)\n\n              Whether the device is battery powered or not.']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/camerastream/frame_skip_rates',
#     'launchStatus': 'BETA',
#     'displayName': 'Frame skip rate'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'DISTRIBUTION',
#     'unit': 'frames/seconds',
#     'monitoredResources': 'assistant_action_project',
#     'description': 'Rate at which camerastream frames are skipped. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['device_type :\n\n              Device type, one of [CAMERA, DOORBELL]',
#      'stream_status :\n\n              The canonical code that represents the result, for example, "COMPLETED" or "FAILED".',
#      'stream_protocol :\n\n              Underlying protocol used for camerastream, for example, "webrtc" or "hls".',
#      'is_battery_powered :\n\n                (BOOL)\n\n              Whether the device is battery powered or not.']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/camerastream/request_count',
#     'launchStatus': 'BETA',
#     'displayName': 'Camerastream request count'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'assistant_action_project',
#     'description': 'Number of camerastream requests since the last sample period. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['device_type :\n\n              Device type, one of [CAMERA, DOORBELL]',
#      'status :\n\n              The canonical code that represents the result, for example, "SUCCESS" or "OFFLINE".',
#      'stream_protocol :\n\n              Underlying protocol used for camerastream, for example, "webrtc" or "hls".',
#      'is_battery_powered :\n\n                (BOOL)\n\n              Whether the device is battery powered or not.']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/camerastream/request_latencies',
#     'launchStatus': 'BETA',
#     'displayName': 'Camerastream request latency'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'DISTRIBUTION',
#     'unit': 'ms',
#     'monitoredResources': 'assistant_action_project',
#     'description': 'Latency for camerastream to start. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['device_type :\n\n              Device type, one of [CAMERA, DOORBELL]',
#      'status :\n\n              The canonical code that represents the result, for example, "SUCCESS" or "OFFLINE".',
#      'stream_protocol :\n\n              Underlying protocol used for camerastream, for example, "webrtc" or "hls".',
#      'is_battery_powered :\n\n                (BOOL)\n\n              Whether the device is battery powered or not.']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/camerastream/signaling_latencies',
#     'launchStatus': 'BETA',
#     'displayName': 'Signaling latency'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'DISTRIBUTION',
#     'unit': 'milliseconds',
#     'monitoredResources': 'assistant_action_project',
#     'description': 'Camerastream signaling latency. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['device_type :\n\n              Device type, one of [CAMERA, DOORBELL]',
#      'stream_status :\n\n              The canonical code that represents the result, for example, "COMPLETED" or "FAILED".',
#      'stream_protocol :\n\n              Underlying protocol used for camerastream, for example, "webrtc" or "hls".',
#      'is_battery_powered :\n\n                (BOOL)\n\n              Whether the device is battery powered or not.']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/camerastream/stream_durations',
#     'launchStatus': 'BETA',
#     'displayName': 'Stream duration'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'DISTRIBUTION',
#     'unit': 'milliseconds',
#     'monitoredResources': 'assistant_action_project',
#     'description': 'Duration of a camerastream. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['device_type :\n\n              Device type, one of [CAMERA, DOORBELL]',
#      'stream_status :\n\n              The canonical code that represents the result, for example, "COMPLETED" or "FAILED".',
#      'stream_protocol :\n\n              Underlying protocol used for camerastream, for example, "webrtc" or "hls".',
#      'is_battery_powered :\n\n                (BOOL)\n\n              Whether the device is battery powered or not.']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/camerastream/webrtc_request_count',
#     'launchStatus': 'BETA',
#     'displayName': 'Webrtc request count'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'assistant_action_project',
#     'description': 'Number of camerastream requests since the last sample period. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['device_type :\n\n              Device type, one of [CAMERA, DOORBELL]',
#      'stream_status :\n\n              The canonical code that represents the result, for example, "COMPLETED" or "FAILED".',
#      'stream_protocol :\n\n              Underlying protocol used for camerastream, for example, "webrtc" or "hls".',
#      'is_battery_powered :\n\n                (BOOL)\n\n              Whether the device is battery powered or not.']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/device_count',
#     'launchStatus': 'ALPHA',
#     'displayName': 'Device count'},
#    'dataInfo': {'kind': 'GAUGE',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'assistant_action_project',
#     'description': 'Counts the device_count based on device_type, software_version, hardware_version, integration_type and is_online. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['device_type :\n\n              Device type, for example, "LIGHT", "LOCK" or "CAMERA".',
#      'software_version :\n\n              The software version of the device, for example, "1.00.062", "1.00.64", "1.00.68", "1.1.1".',
#      'hardware_version :\n\n              The hardware version of the device, for example, "1", "1.0", "1.0.0", "1.0.7".',
#      'integration_type :\n\n              Integration type, one of [local, cloud, matter].',
#      'is_online :\n\n                (BOOL)\n\n              Whether the device is online or not.']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/execution_success_confidence',
#     'launchStatus': 'BETA',
#     'displayName': 'Execution success confidence'},
#    'dataInfo': {'kind': 'GAUGE',
#     'type': 'DOUBLE',
#     'unit': '1',
#     'monitoredResources': 'assistant_action_project',
#     'description': 'Confidence metric (normalized) for current execution success rate compared with past performance. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': []},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/local_event_count',
#     'launchStatus': 'BETA',
#     'displayName': 'Local event count'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'assistant_action_project',
#     'description': 'Count of events that only happens in LocalHomePlatform. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['intent :\n\n              Intent used in SmartHome integration, for example, "EXECUTE", "QUERY", "SYNC".',
#      'status :\n\n              The canonical code that represents the result, for example, "SUCCESS" or "OFFLINE".',
#      'app_version :\n\n              The version of the Local Home SDK app, for example, "0.0.1" or "0.1.2".',
#      'model :\n\n              Model is equivalent to product ID.']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/matter_setup_event_count',
#     'launchStatus': 'BETA',
#     'displayName': 'Matter setup event count'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'assistant_action_project',
#     'description': 'Counts of Setup Events for Matter Launch. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['setup_status :\n\n              The setup status has detailed information about state of setup (commisssioning complete, etc.)',
#      'setup_state :\n\n              The setup state is either Success or Failure.']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/num_active_users',
#     'launchStatus': 'BETA',
#     'displayName': 'Daily active users'},
#    'dataInfo': {'kind': 'GAUGE',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'assistant_action_project',
#     'description': 'Daily active users count. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['device_type :\n\n              Device type, for example, "LIGHT" or "LOCK".',
#      'locale :\n\n              locale, for example, "en-US" or "fr-CA".',
#      'trait :\n\n              Assistant Smarthome trait, for example, "onOff" or "lockUnlock".',
#      'integration_type :\n\n              Integration type, one of [local, cloud, matter].']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/report_state_accuracy',
#     'launchStatus': 'BETA',
#     'displayName': 'Report state accuracy'},
#    'dataInfo': {'kind': 'GAUGE',
#     'type': 'DOUBLE',
#     'unit': '10^2.%',
#     'monitoredResources': 'assistant_action_project',
#     'description': 'The accuracy of the states reported by the partner to HomeGraph compared to the states retrieved by sending a QUERY to the partner. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['device_type :\n\n              Device type, for example, "LIGHT" or "LOCK".',
#      'trait :\n\n              Assistant Smarthome trait, for example, "onOff" or "lockUnlock".',
#      'result :\n\n              The canonical code that represents the result, for example, "ACCURATE", "ACCURATE_BUT_LATE", "INACCURATE".']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/request_count',
#     'launchStatus': 'BETA',
#     'displayName': 'Request count'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'assistant_action_project',
#     'description': 'Request count. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['device_type :\n\n              Device type, for example, "LIGHT" or "LOCK".',
#      'status :\n\n              The canonical code that represents the result, for example, "SUCCESS" or "OFFLINE".',
#      'trait :\n\n              Assistant Smarthome trait, for example, "onOff" or "lockUnlock".',
#      'integration_type :\n\n              Integration type, one of [local, cloud, matter].',
#      'is_local :\n\n                (BOOL)\n\n              Whether the request routed locally or through cloud endpoint.',
#      'execution_type :\n\n              Execution type, one of [execute, query].']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/request_latencies',
#     'launchStatus': 'BETA',
#     'displayName': 'Request latencies'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'DISTRIBUTION',
#     'unit': 'ms',
#     'monitoredResources': 'assistant_action_project',
#     'description': 'Distribution of request latencies. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['device_type :\n\n              Device type, for example, "LIGHT" or "LOCK".',
#      'status :\n\n              The canonical code that represents the result, for example, "SUCCESS" or "OFFLINE".',
#      'trait :\n\n              Assistant Smarthome trait, for example, "onOff" or "lockUnlock".',
#      'is_local :\n\n                (BOOL)\n\n              Whether the request routed locally or through cloud endpoint.',
#      'execution_type :\n\n              Execution type, one of [execute, query].',
#      'integration_type :\n\n              Integration type, one of [local, cloud, matter].']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/seven_day_active_users',
#     'launchStatus': 'BETA',
#     'displayName': '7 day active users'},
#    'dataInfo': {'kind': 'GAUGE',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'assistant_action_project',
#     'description': '7 day active users count. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['device_type :\n\n              Device type, for example, "LIGHT" or "LOCK".',
#      'locale :\n\n              locale, for example, "en-US" or "fr-CA".',
#      'trait :\n\n              Assistant Smarthome trait, for example, "onOff" or "lockUnlock".',
#      'integration_type :\n\n              Integration type, one of [local, cloud, matter].']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'smarthome_action/twenty_eight_day_active_users',
#     'launchStatus': 'BETA',
#     'displayName': '28 day active users'},
#    'dataInfo': {'kind': 'GAUGE',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'assistant_action_project',
#     'description': '28 day active users count. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['device_type :\n\n              Device type, for example, "LIGHT" or "LOCK".',
#      'locale :\n\n              locale, for example, "en-US" or "fr-CA".',
#      'trait :\n\n              Assistant Smarthome trait, for example, "onOff" or "lockUnlock".',
#      'integration_type :\n\n              Integration type, one of [local, cloud, matter].']},
#    'serviceIndex': 0},
#   {'metricInfo': {'name': 'featurestore/cpu_load',
#     'launchStatus': 'BETA',
#     'displayName': 'CPU load'},
#    'dataInfo': {'kind': 'GAUGE',
#     'type': 'DOUBLE',
#     'unit': '10^2.%',
#     'monitoredResources': 'aiplatform.googleapis.com/Featurestore',
#     'description': 'The average CPU load for a node in the Featurestore online storage. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': []},
#    'serviceIndex': 1},
#   {'metricInfo': {'name': 'featurestore/cpu_load_hottest_node',
#     'launchStatus': 'BETA',
#     'displayName': 'CPU load (hottest node)'},
#    'dataInfo': {'kind': 'GAUGE',
#     'type': 'DOUBLE',
#     'unit': '10^2.%',
#     'monitoredResources': 'aiplatform.googleapis.com/Featurestore',
#     'description': 'The CPU load for the hottest node in the Featurestore online storage. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': []},
#    'serviceIndex': 1},
#   {'metricInfo': {'name': 'featurestore/node_count',
#     'launchStatus': 'BETA',
#     'displayName': 'Node count'},
#    'dataInfo': {'kind': 'GAUGE',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'aiplatform.googleapis.com/Featurestore',
#     'description': 'The number of nodes for the Featurestore online storage. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': []},
#    'serviceIndex': 1},
#   {'metricInfo': {'name': 'featurestore/online_entities_updated',
#     'launchStatus': 'BETA',
#     'displayName': 'Entities updated on the Featurestore online storage.'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': 'By',
#     'monitoredResources': 'aiplatform.googleapis.com/Featurestore',
#     'description': 'Number of entities updated on the Featurestore online storage.',
#     'labels': ["type :\n\n              The type of update: 'WRITE', 'DELETE'."]},
#    'serviceIndex': 1},
#   {'metricInfo': {'name': 'featurestore/online_serving/latencies',
#     'launchStatus': 'BETA',
#     'displayName': 'Latencies'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'DISTRIBUTION',
#     'unit': 'ms',
#     'monitoredResources': 'aiplatform.googleapis.com/Featurestore',
#     'description': 'Online serving latencies by EntityType.',
#     'labels': ['entity_type_id :\n\n              EntityType being requested.',
#      'method :\n\n              Online serving method, one of [ReadFeatureValues, StreamingReadFeatureValues].']},
#    'serviceIndex': 1},
#   {'metricInfo': {'name': 'featurestore/online_serving/request_bytes_count',
#     'launchStatus': 'BETA',
#     'displayName': 'Request size'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': 'By',
#     'monitoredResources': 'aiplatform.googleapis.com/Featurestore',
#     'description': 'Request size by EntityType.',
#     'labels': ['entity_type_id :\n\n              EntityType being requested.',
#      'method :\n\n              Streaming write method, one of [ReadFeatureValues, StreamingReadFeatureValues, WriteFeatureValues].']},
#    'serviceIndex': 1},
#   {'metricInfo': {'name': 'featurestore/online_serving/request_count',
#     'launchStatus': 'BETA',
#     'displayName': 'Serving count'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'aiplatform.googleapis.com/Featurestore',
#     'description': 'Featurestore online serving count by EntityType.',
#     'labels': ['entity_type_id :\n\n              EntityType being requested.',
#      'method :\n\n              Online serving method, one of [ReadFeatureValues, StreamingReadFeatureValues].',
#      'error_code :\n\n              Error code.']},
#    'serviceIndex': 1},
#   {'metricInfo': {'name': 'featurestore/online_serving/response_size',
#     'launchStatus': 'BETA',
#     'displayName': 'Response size'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': 'By',
#     'monitoredResources': 'aiplatform.googleapis.com/Featurestore',
#     'description': 'Response size by EntityType.',
#     'labels': ['entity_type_id :\n\n              EntityType being requested.',
#      'method :\n\n              Online serving method, one of [ReadFeatureValues, StreamingReadFeatureValues].']},
#    'serviceIndex': 1},
#   {'metricInfo': {'name': 'featurestore/storage/stored_bytes',
# ...
#     'description': 'The number of sign-ins that have exceeded the free daily new sign-in quota.',
#     'labels': ['pricing_tier :\n\n              The pricing tier of the identity provider used to sign in.']},
#    'serviceIndex': 49},
#   {'metricInfo': {'name': 'recaptcha/risk_scores',
#     'launchStatus': 'BETA',
#     'displayName': 'reCAPTCHA risk score distribution'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'DISTRIBUTION',
#     'unit': '1',
#     'monitoredResources': 'identitytoolkit_tenant',
#     'description': 'Distribution of reCAPTCHA scores. Scores range from 0 (high risk) to 1 (low risk).',
#     'labels': ['provider :\n\n              The identity provider, one of [passwordProvider].',
#      'api_name :\n\n              The reCAPTCHA supported API name, one of [signUp, signInWithPassword, getOobCode].',
#      'client_type :\n\n              Client platform, one of [web, android, ios].']},
#    'serviceIndex': 49},
#   {'metricInfo': {'name': 'recaptcha/token_count',
#     'launchStatus': 'BETA',
#     'displayName': 'reCAPTCHA token count'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'identitytoolkit_tenant',
#     'description': 'Count of reCAPTCHA tokens in different states.',
#     'labels': ['provider :\n\n              The identity provider, one of [passwordProvider].',
#      'api_name :\n\n              The reCAPTCHA supported API name, one of [signUp, signInWithPassword, getOobCode].',
#      'client_type :\n\n              Client platform, one of [web, android, ios].',
#      'token_state :\n\n              The state of a token, one of [expired, duplicate, missing, invalid, valid].']},
#    'serviceIndex': 49},
#   {'metricInfo': {'name': 'recaptcha/verdict_count',
#     'launchStatus': 'BETA',
#     'displayName': 'reCAPTCHA verdicts count'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'identitytoolkit_tenant',
#     'description': 'Count of evaluation results based on the reCAPTCHA configuration.',
#     'labels': ['provider :\n\n              The identity provider, one of [passwordProvider].',
#      'api_name :\n\n              The reCAPTCHA supported API name, one of [signUp, signInWithPassword, getOobCode].',
#      'client_type :\n\n              Client platform, one of [web, android, ios].',
#      'verdict_state :\n\n              The state of a verdict, one of [passed, failed_in_audit, failed_in_enforce].']},
#    'serviceIndex': 49},
#   {'metricInfo': {'name': 'usage/blocked_sms_count',
#     'launchStatus': 'BETA',
#     'displayName': 'Blocked SMS'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'identitytoolkit_project',
#     'description': 'The number of SMS-based verification codes that were blocked from being sent.',
#     'labels': ['pricing_tier :\n\n              The pricing tier of the country where the SMS is sent.',
#      'country_calling_code :\n\n              The country calling code of the phone number where the SMS is sent.',
#      'region_code :\n\n              The two-letter region code of the phone number where the SMS is sent.',
#      'sms_purpose :\n\n              The purpose of the SMS-based verification code (i.e. phone auth, MFA).']},
#    'serviceIndex': 49},
#   {'metricInfo': {'name': 'usage/daily_new_signin_count',
#     'launchStatus': 'BETA',
#     'displayName': 'Daily New Sign-ins'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'identitytoolkit_project',
#     'description': 'The number of new daily active users. A sign-in or token refresh is counted as a new daily active user if the user has not previously signed in that day.',
#     'labels': ['pricing_tier :\n\n              The pricing tier of the identity provider used to sign in.',
#      'is_anon :\n\n              Whether or not the sign-in is an anonymous auth sign-in.']},
#    'serviceIndex': 49},
#   {'metricInfo': {'name': 'usage/monthly_new_signin_count',
#     'launchStatus': 'BETA',
#     'displayName': 'Monthly New Sign-ins'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'identitytoolkit_project',
#     'description': 'The number of new monthly active users. A sign-in or token refresh is counted as a new monthly active user if the user has not previously signed in that month.',
#     'labels': ['pricing_tier :\n\n              The pricing tier of the identity provider used to sign in.',
#      'is_anon :\n\n              Whether or not the sign-in is an anonymous auth sign-in.']},
#    'serviceIndex': 49},
#   {'metricInfo': {'name': 'usage/sent_sms_count',
#     'launchStatus': 'BETA',
#     'displayName': 'Sent SMS'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'identitytoolkit_project',
#     'description': 'The number of SMS-based verification codes sent.',
#     'labels': ['pricing_tier :\n\n              The pricing tier of the country where the SMS is sent.',
#      'country_calling_code :\n\n              The country calling code of the phone number where the SMS is sent.',
#      'region_code :\n\n              The two-letter region code of the phone number where the SMS is sent.',
#      'sms_purpose :\n\n              The purpose of the SMS-based verification code (i.e. phone auth, MFA).']},
#    'serviceIndex': 49},
#   {'metricInfo': {'name': 'usage/verification_sms_count',
#     'launchStatus': 'BETA',
#     'displayName': 'Verified SMS'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'identitytoolkit_project',
#     'description': 'The number of successful SMS-based verifications.',
#     'labels': ['pricing_tier :\n\n              The pricing tier of the country where the SMS is sent.',
#      'country_calling_code :\n\n              The country calling code of the phone number where the SMS is sent.',
#      'region_code :\n\n              The two-letter region code of the phone number where the SMS is sent.',
#      'sms_purpose :\n\n              The purpose of the SMS-based verification code (i.e. phone auth, MFA).']},
#    'serviceIndex': 49},
#   {'metricInfo': {'name': 'received_bytes_count',
#     'launchStatus': 'BETA',
#     'displayName': 'Total IDS Endpoint received bytes'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': 'By',
#     'monitoredResources': 'ids.googleapis.com/Endpoint',
#     'description': 'Total IDS Endpoint received bytes. Sampled every 60 seconds. After sampling, data is not visible for up to 120 seconds.',
#     'labels': []},
#    'serviceIndex': 50},
#   {'metricInfo': {'name': 'received_packets_count',
#     'launchStatus': 'BETA',
#     'displayName': 'Total IDS Endpoint received packets'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '1',
#     'monitoredResources': 'ids.googleapis.com/Endpoint',
#     'description': 'Total IDS Endpoint received packets. Sampled every 60 seconds. After sampling, data is not visible for up to 120 seconds.',
#     'labels': []},
#    'serviceIndex': 50},
#   {'metricInfo': {'name': 'network/attachment/capacity',
#     'launchStatus': 'GA',
#     'displayName': 'Network Capacity'},
#    'dataInfo': {'kind': 'GAUGE',
#     'type': 'INT64',
#     'unit': 'By/s',
#     'monitoredResources': 'interconnect_attachment',
#     'description': 'Network Capacity of the Attachment. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': []},
#    'serviceIndex': 51},
#   {'metricInfo': {'name': 'network/attachment/received_bytes_count',
#     'launchStatus': 'GA',
#     'displayName': 'Ingress Bytes'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': 'By',
#     'monitoredResources': 'interconnect_attachment',
#     'description': 'Number of inbound bytes received. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': []},
#    'serviceIndex': 51},
#   {'metricInfo': {'name': 'network/attachment/received_bytes_count_by_l3_protocol',
#     'launchStatus': 'BETA',
#     'displayName': 'Ingress bytes by L3 protocol'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': 'By',
#     'monitoredResources': 'interconnect_attachment',
#     'description': 'Number of inbound bytes received by L3 Protocol. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['l3_protocol :\n\n              Layer 3 protocol.']},
#    'serviceIndex': 51},
#   {'metricInfo': {'name': 'network/attachment/received_packets_count',
#     'launchStatus': 'GA',
#     'displayName': 'Ingress Packets'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '{packets}',
#     'monitoredResources': 'interconnect_attachment',
#     'description': 'Number of inbound packets received. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': []},
#    'serviceIndex': 51},
#   {'metricInfo': {'name': 'network/attachment/received_packets_count_by_l3_protocol',
#     'launchStatus': 'BETA',
#     'displayName': 'Ingress packets by L3 protocol'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '{packets}',
#     'monitoredResources': 'interconnect_attachment',
#     'description': 'Number of inbound packets received by L3 Protocol. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['l3_protocol :\n\n              Layer 3 protocol.']},
#    'serviceIndex': 51},
#   {'metricInfo': {'name': 'network/attachment/sent_bytes_count',
#     'launchStatus': 'GA',
#     'displayName': 'Egress Bytes'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': 'By',
#     'monitoredResources': 'interconnect_attachment',
#     'description': 'Number of outbound bytes sent. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': []},
#    'serviceIndex': 51},
#   {'metricInfo': {'name': 'network/attachment/sent_bytes_count_by_l3_protocol',
#     'launchStatus': 'BETA',
#     'displayName': 'Egress bytes by L3 protocol'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': 'By',
#     'monitoredResources': 'interconnect_attachment',
#     'description': 'Number of outbound bytes sent by L3 Protocol. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['l3_protocol :\n\n              Layer 3 protocol.']},
#    'serviceIndex': 51},
#   {'metricInfo': {'name': 'network/attachment/sent_packets_count',
#     'launchStatus': 'GA',
#     'displayName': 'Egress Packets'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '{packets}',
#     'monitoredResources': 'interconnect_attachment',
#     'description': 'Number of outbound packets sent. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': []},
#    'serviceIndex': 51},
#   {'metricInfo': {'name': 'network/attachment/sent_packets_count_by_l3_protocol',
#     'launchStatus': 'BETA',
#     'displayName': 'Egress packets by L3 protocol'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'INT64',
#     'unit': '{packets}',
#     'monitoredResources': 'interconnect_attachment',
#     'description': 'Number of outbound packets sent by L3 Protocol. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['l3_protocol :\n\n              Layer 3 protocol.']},
#    'serviceIndex': 51},
#   {'metricInfo': {'name': 'network/interconnect/capacity',
#     'launchStatus': 'GA',
#     'displayName': 'Network Capacity'},
#    'dataInfo': {'kind': 'GAUGE',
#     'type': 'INT64',
#     'unit': 'By/s',
#     'monitoredResources': 'interconnect',
#     'description': 'Active capacity of the interconnect. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': []},
#    'serviceIndex': 51},
#   {'metricInfo': {'name': 'network/interconnect/dropped_packets_count',
#     'launchStatus': 'GA',
#     'displayName': 'Dropped Packets'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'DOUBLE',
#     'unit': '{packets}',
#     'monitoredResources': 'interconnect',
#     'description': 'Number of outbound packets dropped due to link congestion. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': []},
#    'serviceIndex': 51},
#   {'metricInfo': {'name': 'network/interconnect/link/operational',
#     'launchStatus': 'GA',
#     'displayName': 'Circuit Operational Status'},
#    'dataInfo': {'kind': 'GAUGE',
#     'type': 'BOOL',
#     'unit': '',
#     'monitoredResources': 'interconnect',
#     'description': "Whether the operational status of the circuit is 'up'. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.",
#     'labels': ['link_id :\n\n              Identifier for the individual physical circuit.']},
#    'serviceIndex': 51},
#   {'metricInfo': {'name': 'network/interconnect/link/rx_power',
#     'launchStatus': 'GA',
#     'displayName': 'Circuit Receive Power'},
#    'dataInfo': {'kind': 'GAUGE',
#     'type': 'DOUBLE',
#     'unit': '{dBm}',
#     'monitoredResources': 'interconnect',
#     'description': 'Light level received over physical circuit. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['link_id :\n\n              Identifier for the individual physical circuit.',
#      'laser_index :\n\n                (INT64)\n\n              Index of the laser channel on an individual circuit.']},
#    'serviceIndex': 51},
#   {'metricInfo': {'name': 'network/interconnect/link/tx_power',
#     'launchStatus': 'GA',
#     'displayName': 'Circuit Transmit Power'},
#    'dataInfo': {'kind': 'GAUGE',
#     'type': 'DOUBLE',
#     'unit': '{dBm}',
#     'monitoredResources': 'interconnect',
#     'description': 'Light level transmitted over physical circuit. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': ['link_id :\n\n              Identifier for the individual physical circuit.',
#      'laser_index :\n\n                (INT64)\n\n              Index of the laser channel on an individual circuit.']},
#    'serviceIndex': 51},
#   {'metricInfo': {'name': 'network/interconnect/operational',
#     'launchStatus': 'GA',
#     'displayName': 'Operational Status'},
#    'dataInfo': {'kind': 'GAUGE',
#     'type': 'BOOL',
#     'unit': '',
#     'monitoredResources': 'interconnect',
#     'description': "Whether the operational status of the interconnect is 'up'. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.",
#     'labels': []},
#    'serviceIndex': 51},
#   {'metricInfo': {'name': 'network/interconnect/receive_errors_count',
#     'launchStatus': 'GA',
#     'displayName': 'Ingress Errors'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'DOUBLE',
#     'unit': '{errors}',
#     'monitoredResources': 'interconnect',
#     'description': 'Number of errors encountered while receiving packets. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': []},
#    'serviceIndex': 51},
#   {'metricInfo': {'name': 'network/interconnect/received_bytes_count',
#     'launchStatus': 'GA',
#     'displayName': 'Ingress Bytes'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'DOUBLE',
#     'unit': 'By',
#     'monitoredResources': 'interconnect',
#     'description': 'Number of inbound bytes received. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': []},
#    'serviceIndex': 51},
#   {'metricInfo': {'name': 'network/interconnect/received_unicast_packets_count',
#     'launchStatus': 'GA',
#     'displayName': 'Ingress Unicast Packets'},
#    'dataInfo': {'kind': 'DELTA',
#     'type': 'DOUBLE',
#     'unit': '{packets}',
#     'monitoredResources': 'interconnect',
#     'description': 'Number of inbound unicast packets received. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#     'labels': []},
#    'serviceIndex': 51},
#   ...]}

# %%
serviceData = data['service']

# %%
serviceDatum = serviceData[0]
serviceDatum
# Out:
# {'name': 'actions',
#  'launchStates': 'Metrics from Google Assistant Smart Home. Launch stages of these metrics: ALPHA BETA',
#  'description': 'The "metric type" strings in this table must be prefixed with actions.googleapis.com/. That prefix has been omitted from the entries in the table.',
#  'serviceIndex': 0}

# %%
launchParts = serviceDatum['launchStates'].split(' Launch stages of these metrics: ')
launchParts
# Out:
# ['Metrics from Google Assistant Smart Home.', 'ALPHA BETA']

# %%
source = re.match('Metrics from (.*)\.', launchParts[0])
source.group(1)
# Out:
# 'Google Assistant Smart Home'

# %%
reorgedData = []
failedItems = []
for serviceDatum in serviceData:
    print(serviceDatum)

    try:

        lauchStates = serviceDatum['launchStates']
        launchParts = lauchStates.split(' Launch stages of these metrics: ')
        launchStages = launchParts[1]
        sourceMatch = re.match('Metrics from (.*)\.?', launchParts[0])
        source = sourceMatch.group(1)
        prefixMatch = re.match('The "metric type" strings in this table must be prefixed with ([a-z\.]*)/. That prefix has been omitted from the entries in the table.', serviceDatum['description'])
        prefix = prefixMatch.group(1)


        if len(launchParts) !=2 or not source or len(launchStages) ==0 or not prefix:
            raise Exception(f'invalid launch states: "{lauchStates}"')
        
    except:
        failedItems.append(serviceDatum)
        continue

    reorgedDatum = {
        'name': serviceDatum['name'],
        'source': source,
        'launchStages': launchStages,
        'prefix': prefix,
        'serviceIndex': serviceDatum['serviceIndex']
    }

    reorgedData.append(reorgedDatum)
# Out:
# {'name': 'actions', 'launchStates': 'Metrics from Google Assistant Smart Home. Launch stages of these metrics: ALPHA BETA', 'description': 'The "metric type" strings in this table must be prefixed with actions.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 0}
# {'name': 'aiplatform', 'launchStates': 'Metrics from Vertex AI. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with aiplatform.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 1}
# {'name': 'alloydb', 'launchStates': 'Metrics from AlloyDB for PostgreSQL. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with alloydb.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 2}
# {'name': 'apigateway', 'launchStates': 'Metrics from API Gateway. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with apigateway.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 3}
# {'name': 'apigee', 'launchStates': 'Metrics from Apigee. Launch stages of these metrics: ALPHA BETA', 'description': 'The "metric type" strings in this table must be prefixed with apigee.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 4}
# {'name': 'appengine', 'launchStates': 'Metrics from App Engine. Note: If you use App Engine flexible environment in combination with Cloud Load Balancing, then certain metrics in the following table are reported as metrics from the loadbalancing table instead. For more information, see External HTTP(S) load balancer logging and monitoring. Launch stages of these metrics: ALPHA BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with appengine.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 5}
# {'name': 'autoscaler', 'launchStates': 'Metrics from Compute Engine Autoscaler. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with autoscaler.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 6}
# {'name': 'baremetalsolution', 'launchStates': 'Metrics from Bare Metal Solution Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with baremetalsolution.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 7}
# {'name': 'GA', 'launchStates': '', 'description': 'The "metric type" strings in this table must be prefixed with bigquery.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 8}
# {'name': 'bigquerybiengine', 'launchStates': 'Metrics from BigQuery BI Engine. Launch stages of these metrics: GA', 'description': 'The "metric type" strings in this table must be prefixed with bigquerybiengine.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 9}
# {'name': 'bigquerydatatransfer', 'launchStates': 'Metrics from the BigQuery Data Transfer Service. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with bigquerydatatransfer.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 10}
# {'name': 'bigquerystorage', 'launchStates': 'Metrics from the BigQuery Storage API. Launch stages of these metrics: ALPHA BETA', 'description': 'The "metric type" strings in this table must be prefixed with bigquerystorage.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 11}
# {'name': 'bigtable', 'launchStates': 'Metrics from Cloud Bigtable. Launch stages of these metrics: EARLY_ACCESS GA', 'description': 'The "metric type" strings in this table must be prefixed with bigtable.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 12}
# {'name': 'certificatemanager', 'launchStates': 'Metrics from Certificate Manager. Launch stages of these metrics: GA', 'description': 'The "metric type" strings in this table must be prefixed with certificatemanager.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 13}
# {'name': 'clouddeploy', 'launchStates': 'Metrics from Google Cloud Deploy. Launch stages of these metrics: GA', 'description': 'The "metric type" strings in this table must be prefixed with clouddeploy.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 14}
# {'name': 'cloudfunctions', 'launchStates': 'Metrics from Cloud Functions. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with cloudfunctions.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 15}
# {'name': 'cloudiot', 'launchStates': 'Metrics from IoT Core. Launch stages of these metrics: GA', 'description': 'The "metric type" strings in this table must be prefixed with cloudiot.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 16}
# {'name': 'cloudkms', 'launchStates': 'Metrics from Cloud Key Management Service. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with cloudkms.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 17}
# {'name': 'cloudsql', 'launchStates': 'Metrics from Cloud SQL. Launch stages of these metrics: ALPHA BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with cloudsql.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 18}
# {'name': 'GA', 'launchStates': '', 'description': 'The "metric type" strings in this table must be prefixed with cloudtasks.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 19}
# {'name': 'cloudtrace', 'launchStates': 'Metrics from Cloud Trace. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with cloudtrace.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 20}
# {'name': 'composer', 'launchStates': 'Metrics from Cloud Composer. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with composer.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 21}
# {'name': 'GA', 'launchStates': '', 'description': 'The "metric type" strings in this table must be prefixed with compute.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 22}
# {'name': 'contactcenterinsights', 'launchStates': 'Metrics from Contact Center AI Insights. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with contactcenterinsights.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 23}
# {'name': 'container', 'launchStates': 'Metrics from Google Kubernetes Engine. For newer Kubernetes metrics, see the kubernetes.io metrics.', 'description': 'The "metric type" strings in this table must be prefixed with container.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 24}
# {'name': 'dataflow', 'launchStates': 'Metrics from Dataflow. For more information about Dataflow monitoring, see Monitoring Dataflow pipelines and Dataflow monitoring interface. Launch stages of these metrics: ALPHA BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with dataflow.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 25}
# {'name': 'datamigration', 'launchStates': 'Metrics from Database Migration. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with datamigration.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 26}
# {'name': 'dataplex', 'launchStates': 'Metrics from Dataplex. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with dataplex.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 27}
# {'name': 'dataproc', 'launchStates': 'Metrics from Dataproc. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with dataproc.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 28}
# {'name': 'datastore', 'launchStates': 'Metrics from Datastore. Launch stages of these metrics: GA', 'description': 'The "metric type" strings in this table must be prefixed with datastore.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 29}
# {'name': 'datastream', 'launchStates': 'Metrics from Datastream. Launch stages of these metrics: ALPHA BETA', 'description': 'The "metric type" strings in this table must be prefixed with datastream.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 30}
# {'name': 'dbinsights', 'launchStates': 'Metrics from Cloud SQL for MySQL. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with dbinsights.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 31}
# {'name': 'dlp', 'launchStates': 'Metrics from Cloud Data Loss Prevention. Launch stages of these metrics: ALPHA BETA', 'description': 'The "metric type" strings in this table must be prefixed with dlp.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 32}
# {'name': 'dns', 'launchStates': 'Metrics from Cloud DNS. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with dns.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 33}
# {'name': 'earthengine', 'launchStates': 'Metrics from Earth Engine. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with earthengine.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 34}
# {'name': 'edgecache', 'launchStates': 'Metrics from Media CDN. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with edgecache.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 35}
# {'name': 'edgecontainer', 'launchStates': 'Metrics from Edge Container. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with edgecontainer.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 36}
# {'name': 'file', 'launchStates': 'Metrics from Filestore. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with file.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 37}
# {'name': 'firebaseappcheck', 'launchStates': 'Metrics from Firebase. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with firebaseappcheck.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 38}
# {'name': 'firebasedatabase', 'launchStates': 'Metrics from Firebase. Launch stages of these metrics: GA', 'description': 'The "metric type" strings in this table must be prefixed with firebasedatabase.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 39}
# {'name': 'firebaseextensions', 'launchStates': 'Metrics from Firebase. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with firebaseextensions.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 40}
# {'name': 'firebasehosting', 'launchStates': 'Metrics from Firebase. Launch stages of these metrics: GA', 'description': 'The "metric type" strings in this table must be prefixed with firebasehosting.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 41}
# {'name': 'firebasestorage', 'launchStates': 'Metrics from Cloud Storage for Firebase. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with firebasestorage.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 42}
# {'name': 'firestore', 'launchStates': 'Metrics from Firestore. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with firestore.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 43}
# {'name': 'firewallinsights', 'launchStates': 'Metrics from Firewall Insights. Launch stages of these metrics: GA', 'description': 'The "metric type" strings in this table must be prefixed with firewallinsights.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 44}
# {'name': 'fleetengine', 'launchStates': 'Metrics from Fleet Engine. Launch stages of these metrics: GA', 'description': 'The "metric type" strings in this table must be prefixed with fleetengine.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 45}
# {'name': 'gkebackup', 'launchStates': 'Metrics from Backup for GKE. Launch stages of these metrics: GA', 'description': 'The "metric type" strings in this table must be prefixed with gkebackup.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 46}
# {'name': 'healthcare', 'launchStates': 'Metrics from Cloud Healthcare API. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with healthcare.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 47}
# {'name': 'iam', 'launchStates': 'Metrics from Identity and Access Management. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with iam.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 48}
# {'name': 'identitytoolkit', 'launchStates': 'Metrics from Identity Platform. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with identitytoolkit.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 49}
# {'name': 'ids', 'launchStates': 'Metrics from Cloud IDS. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with ids.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 50}
# {'name': 'interconnect', 'launchStates': 'Metrics from Cloud Interconnect. For Dedicated Interconnect, Monitoring and Google Cloud collect measurements for the network/interconnect and network/attachment metric types. For Partner Interconnect, Monitoring and Google Cloud collect measurements for the network/attachment metric type only. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with interconnect.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 51}
# {'name': 'livestream', 'launchStates': 'Metrics for Live Stream API. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with livestream.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 52}
# {'name': 'loadbalancing', 'launchStates': 'Metrics for Cloud Load Balancing. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with loadbalancing.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 53}
# {'name': 'logging', 'launchStates': 'Metrics from Cloud Logging. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with logging.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 54}
# {'name': 'managedidentities', 'launchStates': 'Metrics from Managed Service for Microsoft Active Directory. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with managedidentities.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 55}
# {'name': 'maps', 'launchStates': 'Metrics from Google Maps Platform. Launch stages of these metrics: GA', 'description': 'The "metric type" strings in this table must be prefixed with maps.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 56}
# {'name': 'memcache', 'launchStates': 'Metrics from Memorystore for Memcached. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with memcache.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 57}
# {'name': 'metastore', 'launchStates': 'Metrics from Dataproc Metastore. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with metastore.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 58}
# {'name': 'ml', 'launchStates': 'Metrics from AI Platform (formerly Cloud Machine Learning). Launch stages of these metrics: ALPHA BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with ml.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 59}
# {'name': 'monitoring', 'launchStates': 'Metrics from Cloud Monitoring. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with monitoring.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 60}
# {'name': 'networking', 'launchStates': 'Metrics from Network Topology. Launch stages of these metrics: ALPHA BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with networking.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 61}
# {'name': 'networksecurity', 'launchStates': 'Metrics from Google Cloud Armor. Launch stages of these metrics: GA', 'description': 'The "metric type" strings in this table must be prefixed with networksecurity.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 62}
# {'name': 'osconfig', 'launchStates': 'Metrics from VM Manager. Launch stages of these metrics: GA', 'description': 'The "metric type" strings in this table must be prefixed with osconfig.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 63}
# {'name': 'privateca', 'launchStates': 'Metrics from Certificate Authority Service. Launch stages of these metrics: GA', 'description': 'The "metric type" strings in this table must be prefixed with privateca.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 64}
# {'name': 'pubsub', 'launchStates': 'Metrics from Pub/Sub. For more information, see Pub/Sub monitoring. Launch stages of these metrics: ALPHA BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with pubsub.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 65}
# {'name': 'pubsublite', 'launchStates': 'Metrics from Pub/Sub Lite. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with pubsublite.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 66}
# {'name': 'recaptchaenterprise', 'launchStates': 'Metrics from reCAPTCHA Enterprise. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with recaptchaenterprise.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 67}
# {'name': 'recommendationengine', 'launchStates': 'Metrics from Recommendations AI. Launch stages of these metrics: EARLY_ACCESS', 'description': 'The "metric type" strings in this table must be prefixed with recommendationengine.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 68}
# {'name': 'redis', 'launchStates': 'Metrics from Memorystore for Redis. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with redis.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 69}
# {'name': 'router', 'launchStates': 'Metrics from Cloud Router. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with router.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 70}
# {'name': 'run', 'launchStates': 'Metrics from managed Cloud Run. (For Cloud Run for Anthos metrics, see Kubernetes metrics and Knative metrics.) Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with run.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 71}
# {'name': 'serviceruntime', 'launchStates': 'Metrics available to all Google Cloud APIs (resource type consumed_api) and to your APIs created with Cloud Endpoints (resource type api). Not all APIs use serviceruntime metrics; for example, the Datastore API does not. The resources listed for the metrics are at launch stage GA, except for api, which is at launch stage BETA.', 'description': 'The "metric type" strings in this table must be prefixed with serviceruntime.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 72}
# {'name': 'spanner', 'launchStates': 'Metrics from Cloud Spanner. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with spanner.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 73}
# {'name': 'storage', 'launchStates': 'Metrics from Cloud Storage. Launch stages of these metrics: BETA GA', 'description': 'The "metric type" strings in this table must be prefixed with storage.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 74}
# {'name': 'storagetransfer', 'launchStates': 'Metrics from Storage Transfer Service. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with storagetransfer.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 75}
# {'name': 'tpu', 'launchStates': 'Metrics from Cloud TPU. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with tpu.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 76}
# {'name': 'trafficdirector', 'launchStates': 'Metrics from Traffic Director. Launch stages of these metrics: GA', 'description': 'The "metric type" strings in this table must be prefixed with trafficdirector.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 77}
# {'name': 'transferappliance', 'launchStates': 'Metrics from Transfer Appliance. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with transferappliance.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 78}
# {'name': 'videostitcher', 'launchStates': 'Metrics from Video Stitcher API. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with videostitcher.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 79}
# {'name': 'visionai', 'launchStates': 'Metrics from Vision AI. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with visionai.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 80}
# {'name': 'vpc access', 'launchStates': 'Metrics from Virtual Private Cloud (VPC). Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with vpcaccess.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 81}
# {'name': 'vpn', 'launchStates': 'Metrics from Cloud VPN. Launch stages of these metrics: GA', 'description': 'The "metric type" strings in this table must be prefixed with vpn.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 82}
# {'name': 'workflows', 'launchStates': 'Metrics from Workflows. Launch stages of these metrics: BETA', 'description': 'The "metric type" strings in this table must be prefixed with workflows.googleapis.com/. That prefix has been omitted from the entries in the table.', 'serviceIndex': 83}

# %%
(len(reorgedData), len(failedItems))
# Out:
# (77, 7)

# %%
failedItems
# Out:
# [{'name': 'GA',
#   'launchStates': '',
#   'description': 'The "metric type" strings in this table must be prefixed with bigquery.googleapis.com/. That prefix has been omitted from the entries in the table.',
#   'serviceIndex': 8},
#  {'name': 'GA',
#   'launchStates': '',
#   'description': 'The "metric type" strings in this table must be prefixed with cloudtasks.googleapis.com/. That prefix has been omitted from the entries in the table.',
#   'serviceIndex': 19},
#  {'name': 'GA',
#   'launchStates': '',
#   'description': 'The "metric type" strings in this table must be prefixed with compute.googleapis.com/. That prefix has been omitted from the entries in the table.',
#   'serviceIndex': 22},
#  {'name': 'container',
#   'launchStates': 'Metrics from Google Kubernetes Engine. For newer Kubernetes metrics, see the kubernetes.io metrics.',
#   'description': 'The "metric type" strings in this table must be prefixed with container.googleapis.com/. That prefix has been omitted from the entries in the table.',
#   'serviceIndex': 24},
#  {'name': 'livestream',
#   'launchStates': 'Metrics for Live Stream API. Launch stages of these metrics: BETA',
#   'description': 'The "metric type" strings in this table must be prefixed with livestream.googleapis.com/. That prefix has been omitted from the entries in the table.',
#   'serviceIndex': 52},
#  {'name': 'loadbalancing',
#   'launchStates': 'Metrics for Cloud Load Balancing. Launch stages of these metrics: BETA GA',
#   'description': 'The "metric type" strings in this table must be prefixed with loadbalancing.googleapis.com/. That prefix has been omitted from the entries in the table.',
#   'serviceIndex': 53},
#  {'name': 'serviceruntime',
#   'launchStates': 'Metrics available to all Google Cloud APIs (resource type consumed_api) and to your APIs created with Cloud Endpoints (resource type api). Not all APIs use serviceruntime metrics; for example, the Datastore API does not. The resources listed for the metrics are at launch stage GA, except for api, which is at launch stage BETA.',
#   'description': 'The "metric type" strings in this table must be prefixed with serviceruntime.googleapis.com/. That prefix has been omitted from the entries in the table.',
#   'serviceIndex': 72}]

# %%
correctedItems = [
    {'name': 'bigquery',
     'source': 'BigQuery',
     'launchStages': 'BETA EARLY_ACCESS GA',
     'prefix': 'bigquery.googleapis.com',
     'serviceIndex': 8,
     },
    {'name': 'cloudtasks',
     'source': 'Cloud Tasks (formerly App Engine Task Queue)',
     'launchStages': 'BETA GA',
     'prefix': 'cloudtasks.googleapis.com',
     'serviceIndex': 19,
     },
    {'name': 'compute',
     'source': ' Compute Engine',
     'launchStages': 'ALPHA BETA GA',
     'prefix': 'compute.googleapis.com',
     'serviceIndex': 22,
     },
    {'name': 'container',
     'source': 'Google Kubernetes Engine',
     'launchStages': '',
     'prefix': 'container.googleapis.com',
     'serviceIndex': 24,
     },
    {'name': 'livestream',
     'source': 'Live Stream API',
     'launchStages': 'BETA',
     'prefix': 'livestream.googleapis.com',
     'serviceIndex': 52,
     },
    {'name': 'loadbalancing',
     'source': 'Cloud Load Balancing',
     'launchStages': 'BETA GA',
     'prefix': 'loadbalancing.googleapis.com',
     'serviceIndex': 53,
     },
    {'name': 'serviceruntime',
     'source': 'all Google Cloud APIs (resource type consumed_api) and to your APIs created with Cloud Endpoints (resource type api)',
     'launchStages': '',
     'prefix': 'serviceruntime.googleapis.com',
     'serviceIndex': 72,
     }
]

# %%
allReorgedData = reorgedData + correctedItems
allReorgedData.sort(key=lambda x: x['serviceIndex'])
allReorgedData
# Out:
# [{'name': 'actions',
#   'source': 'Google Assistant Smart Home.',
#   'launchStages': 'ALPHA BETA',
#   'prefix': 'actions.googleapis.com',
#   'serviceIndex': 0},
#  {'name': 'aiplatform',
#   'source': 'Vertex AI.',
#   'launchStages': 'BETA',
#   'prefix': 'aiplatform.googleapis.com',
#   'serviceIndex': 1},
#  {'name': 'alloydb',
#   'source': 'AlloyDB for PostgreSQL.',
#   'launchStages': 'BETA GA',
#   'prefix': 'alloydb.googleapis.com',
#   'serviceIndex': 2},
#  {'name': 'apigateway',
#   'source': 'API Gateway.',
#   'launchStages': 'BETA',
#   'prefix': 'apigateway.googleapis.com',
#   'serviceIndex': 3},
#  {'name': 'apigee',
#   'source': 'Apigee.',
#   'launchStages': 'ALPHA BETA',
#   'prefix': 'apigee.googleapis.com',
#   'serviceIndex': 4},
#  {'name': 'appengine',
#   'source': 'App Engine. Note: If you use App Engine flexible environment in combination with Cloud Load Balancing, then certain metrics in the following table are reported as metrics from the loadbalancing table instead. For more information, see External HTTP(S) load balancer logging and monitoring.',
#   'launchStages': 'ALPHA BETA GA',
#   'prefix': 'appengine.googleapis.com',
#   'serviceIndex': 5},
#  {'name': 'autoscaler',
#   'source': 'Compute Engine Autoscaler.',
#   'launchStages': 'BETA',
#   'prefix': 'autoscaler.googleapis.com',
#   'serviceIndex': 6},
#  {'name': 'baremetalsolution',
#   'source': 'Bare Metal Solution',
#   'launchStages': 'BETA',
#   'prefix': 'baremetalsolution.googleapis.com',
#   'serviceIndex': 7},
#  {'name': 'bigquery',
#   'source': 'BigQuery',
#   'launchStages': 'BETA EARLY_ACCESS GA',
#   'prefix': 'bigquery.googleapis.com',
#   'serviceIndex': 8},
#  {'name': 'bigquerybiengine',
#   'source': 'BigQuery BI Engine.',
#   'launchStages': 'GA',
#   'prefix': 'bigquerybiengine.googleapis.com',
#   'serviceIndex': 9},
#  {'name': 'bigquerydatatransfer',
#   'source': 'the BigQuery Data Transfer Service.',
#   'launchStages': 'BETA',
#   'prefix': 'bigquerydatatransfer.googleapis.com',
#   'serviceIndex': 10},
#  {'name': 'bigquerystorage',
#   'source': 'the BigQuery Storage API.',
#   'launchStages': 'ALPHA BETA',
#   'prefix': 'bigquerystorage.googleapis.com',
#   'serviceIndex': 11},
#  {'name': 'bigtable',
#   'source': 'Cloud Bigtable.',
#   'launchStages': 'EARLY_ACCESS GA',
#   'prefix': 'bigtable.googleapis.com',
#   'serviceIndex': 12},
#  {'name': 'certificatemanager',
#   'source': 'Certificate Manager.',
#   'launchStages': 'GA',
#   'prefix': 'certificatemanager.googleapis.com',
#   'serviceIndex': 13},
#  {'name': 'clouddeploy',
#   'source': 'Google Cloud Deploy.',
#   'launchStages': 'GA',
#   'prefix': 'clouddeploy.googleapis.com',
#   'serviceIndex': 14},
#  {'name': 'cloudfunctions',
#   'source': 'Cloud Functions.',
#   'launchStages': 'BETA GA',
#   'prefix': 'cloudfunctions.googleapis.com',
#   'serviceIndex': 15},
#  {'name': 'cloudiot',
#   'source': 'IoT Core.',
#   'launchStages': 'GA',
#   'prefix': 'cloudiot.googleapis.com',
#   'serviceIndex': 16},
#  {'name': 'cloudkms',
#   'source': 'Cloud Key Management Service.',
#   'launchStages': 'BETA GA',
#   'prefix': 'cloudkms.googleapis.com',
#   'serviceIndex': 17},
#  {'name': 'cloudsql',
#   'source': 'Cloud SQL.',
#   'launchStages': 'ALPHA BETA GA',
#   'prefix': 'cloudsql.googleapis.com',
#   'serviceIndex': 18},
#  {'name': 'cloudtasks',
#   'source': 'Cloud Tasks (formerly App Engine Task Queue)',
#   'launchStages': 'BETA GA',
#   'prefix': 'cloudtasks.googleapis.com',
#   'serviceIndex': 19},
#  {'name': 'cloudtrace',
#   'source': 'Cloud Trace.',
#   'launchStages': 'BETA GA',
#   'prefix': 'cloudtrace.googleapis.com',
#   'serviceIndex': 20},
#  {'name': 'composer',
#   'source': 'Cloud Composer.',
#   'launchStages': 'BETA',
#   'prefix': 'composer.googleapis.com',
#   'serviceIndex': 21},
#  {'name': 'compute',
#   'source': ' Compute Engine',
#   'launchStages': 'ALPHA BETA GA',
#   'prefix': 'compute.googleapis.com',
#   'serviceIndex': 22},
#  {'name': 'contactcenterinsights',
#   'source': 'Contact Center AI Insights.',
#   'launchStages': 'BETA',
#   'prefix': 'contactcenterinsights.googleapis.com',
#   'serviceIndex': 23},
#  {'name': 'container',
#   'source': 'Google Kubernetes Engine',
#   'launchStages': '',
#   'prefix': 'container.googleapis.com',
#   'serviceIndex': 24},
#  {'name': 'dataflow',
#   'source': 'Dataflow. For more information about Dataflow monitoring, see Monitoring Dataflow pipelines and Dataflow monitoring interface.',
#   'launchStages': 'ALPHA BETA GA',
#   'prefix': 'dataflow.googleapis.com',
#   'serviceIndex': 25},
#  {'name': 'datamigration',
#   'source': 'Database Migration.',
#   'launchStages': 'BETA',
#   'prefix': 'datamigration.googleapis.com',
#   'serviceIndex': 26},
#  {'name': 'dataplex',
#   'source': 'Dataplex.',
#   'launchStages': 'BETA',
#   'prefix': 'dataplex.googleapis.com',
#   'serviceIndex': 27},
#  {'name': 'dataproc',
#   'source': 'Dataproc.',
#   'launchStages': 'BETA GA',
#   'prefix': 'dataproc.googleapis.com',
#   'serviceIndex': 28},
#  {'name': 'datastore',
#   'source': 'Datastore.',
#   'launchStages': 'GA',
#   'prefix': 'datastore.googleapis.com',
#   'serviceIndex': 29},
#  {'name': 'datastream',
#   'source': 'Datastream.',
#   'launchStages': 'ALPHA BETA',
#   'prefix': 'datastream.googleapis.com',
#   'serviceIndex': 30},
#  {'name': 'dbinsights',
#   'source': 'Cloud SQL for MySQL.',
#   'launchStages': 'BETA',
#   'prefix': 'dbinsights.googleapis.com',
#   'serviceIndex': 31},
#  {'name': 'dlp',
#   'source': 'Cloud Data Loss Prevention.',
#   'launchStages': 'ALPHA BETA',
#   'prefix': 'dlp.googleapis.com',
#   'serviceIndex': 32},
#  {'name': 'dns',
#   'source': 'Cloud DNS.',
#   'launchStages': 'BETA',
#   'prefix': 'dns.googleapis.com',
#   'serviceIndex': 33},
#  {'name': 'earthengine',
#   'source': 'Earth Engine.',
#   'launchStages': 'BETA',
#   'prefix': 'earthengine.googleapis.com',
#   'serviceIndex': 34},
#  {'name': 'edgecache',
#   'source': 'Media CDN.',
#   'launchStages': 'BETA',
#   'prefix': 'edgecache.googleapis.com',
#   'serviceIndex': 35},
#  {'name': 'edgecontainer',
#   'source': 'Edge Container.',
#   'launchStages': 'BETA',
#   'prefix': 'edgecontainer.googleapis.com',
#   'serviceIndex': 36},
#  {'name': 'file',
#   'source': 'Filestore.',
#   'launchStages': 'BETA GA',
#   'prefix': 'file.googleapis.com',
#   'serviceIndex': 37},
#  {'name': 'firebaseappcheck',
#   'source': 'Firebase.',
#   'launchStages': 'BETA',
#   'prefix': 'firebaseappcheck.googleapis.com',
#   'serviceIndex': 38},
#  {'name': 'firebasedatabase',
#   'source': 'Firebase.',
#   'launchStages': 'GA',
#   'prefix': 'firebasedatabase.googleapis.com',
#   'serviceIndex': 39},
#  {'name': 'firebaseextensions',
#   'source': 'Firebase.',
#   'launchStages': 'BETA',
#   'prefix': 'firebaseextensions.googleapis.com',
#   'serviceIndex': 40},
#  {'name': 'firebasehosting',
#   'source': 'Firebase.',
#   'launchStages': 'GA',
#   'prefix': 'firebasehosting.googleapis.com',
#   'serviceIndex': 41},
#  {'name': 'firebasestorage',
#   'source': 'Cloud Storage for Firebase.',
#   'launchStages': 'BETA',
#   'prefix': 'firebasestorage.googleapis.com',
#   'serviceIndex': 42},
#  {'name': 'firestore',
#   'source': 'Firestore.',
#   'launchStages': 'BETA GA',
#   'prefix': 'firestore.googleapis.com',
#   'serviceIndex': 43},
#  {'name': 'firewallinsights',
#   'source': 'Firewall Insights.',
#   'launchStages': 'GA',
#   'prefix': 'firewallinsights.googleapis.com',
#   'serviceIndex': 44},
#  {'name': 'fleetengine',
#   'source': 'Fleet Engine.',
#   'launchStages': 'GA',
#   'prefix': 'fleetengine.googleapis.com',
#   'serviceIndex': 45},
#  {'name': 'gkebackup',
#   'source': 'Backup for GKE.',
#   'launchStages': 'GA',
#   'prefix': 'gkebackup.googleapis.com',
#   'serviceIndex': 46},
#  {'name': 'healthcare',
#   'source': 'Cloud Healthcare API.',
#   'launchStages': 'BETA',
#   'prefix': 'healthcare.googleapis.com',
#   'serviceIndex': 47},
#  {'name': 'iam',
#   'source': 'Identity and Access Management.',
#   'launchStages': 'BETA GA',
#   'prefix': 'iam.googleapis.com',
#   'serviceIndex': 48},
#  {'name': 'identitytoolkit',
#   'source': 'Identity Platform.',
#   'launchStages': 'BETA',
#   'prefix': 'identitytoolkit.googleapis.com',
#   'serviceIndex': 49},
#  {'name': 'ids',
#   'source': 'Cloud IDS.',
#   'launchStages': 'BETA',
#   'prefix': 'ids.googleapis.com',
#   'serviceIndex': 50},
#  {'name': 'interconnect',
#   'source': 'Cloud Interconnect. For Dedicated Interconnect, Monitoring and Google Cloud collect measurements for the network/interconnect and network/attachment metric types. For Partner Interconnect, Monitoring and Google Cloud collect measurements for the network/attachment metric type only.',
#   'launchStages': 'BETA GA',
#   'prefix': 'interconnect.googleapis.com',
#   'serviceIndex': 51},
#  {'name': 'livestream',
#   'source': 'Live Stream API',
#   'launchStages': 'BETA',
#   'prefix': 'livestream.googleapis.com',
#   'serviceIndex': 52},
#  {'name': 'loadbalancing',
#   'source': 'Cloud Load Balancing',
#   'launchStages': 'BETA GA',
#   'prefix': 'loadbalancing.googleapis.com',
#   'serviceIndex': 53},
#  {'name': 'logging',
#   'source': 'Cloud Logging.',
#   'launchStages': 'BETA GA',
#   'prefix': 'logging.googleapis.com',
#   'serviceIndex': 54},
#  {'name': 'managedidentities',
#   'source': 'Managed Service for Microsoft Active Directory.',
#   'launchStages': 'BETA',
#   'prefix': 'managedidentities.googleapis.com',
#   'serviceIndex': 55},
#  {'name': 'maps',
#   'source': 'Google Maps Platform.',
#   'launchStages': 'GA',
#   'prefix': 'maps.googleapis.com',
#   'serviceIndex': 56},
#  {'name': 'memcache',
#   'source': 'Memorystore for Memcached.',
#   'launchStages': 'BETA',
#   'prefix': 'memcache.googleapis.com',
#   'serviceIndex': 57},
#  {'name': 'metastore',
#   'source': 'Dataproc Metastore.',
#   'launchStages': 'BETA GA',
#   'prefix': 'metastore.googleapis.com',
#   'serviceIndex': 58},
#  {'name': 'ml',
#   'source': 'AI Platform (formerly Cloud Machine Learning).',
#   'launchStages': 'ALPHA BETA GA',
#   'prefix': 'ml.googleapis.com',
#   'serviceIndex': 59},
#  {'name': 'monitoring',
#   'source': 'Cloud Monitoring.',
#   'launchStages': 'BETA GA',
#   'prefix': 'monitoring.googleapis.com',
#   'serviceIndex': 60},
#  {'name': 'networking',
#   'source': 'Network Topology.',
#   'launchStages': 'ALPHA BETA GA',
#   'prefix': 'networking.googleapis.com',
#   'serviceIndex': 61},
#  {'name': 'networksecurity',
#   'source': 'Google Cloud Armor.',
#   'launchStages': 'GA',
#   'prefix': 'networksecurity.googleapis.com',
#   'serviceIndex': 62},
#  {'name': 'osconfig',
#   'source': 'VM Manager.',
#   'launchStages': 'GA',
#   'prefix': 'osconfig.googleapis.com',
#   'serviceIndex': 63},
#  {'name': 'privateca',
#   'source': 'Certificate Authority Service.',
#   'launchStages': 'GA',
#   'prefix': 'privateca.googleapis.com',
#   'serviceIndex': 64},
#  {'name': 'pubsub',
#   'source': 'Pub/Sub. For more information, see Pub/Sub monitoring.',
#   'launchStages': 'ALPHA BETA GA',
#   'prefix': 'pubsub.googleapis.com',
#   'serviceIndex': 65},
#  {'name': 'pubsublite',
#   'source': 'Pub/Sub Lite.',
#   'launchStages': 'BETA GA',
#   'prefix': 'pubsublite.googleapis.com',
#   'serviceIndex': 66},
#  {'name': 'recaptchaenterprise',
#   'source': 'reCAPTCHA Enterprise.',
#   'launchStages': 'BETA',
#   'prefix': 'recaptchaenterprise.googleapis.com',
#   'serviceIndex': 67},
#  {'name': 'recommendationengine',
#   'source': 'Recommendations AI.',
#   'launchStages': 'EARLY_ACCESS',
#   'prefix': 'recommendationengine.googleapis.com',
#   'serviceIndex': 68},
#  {'name': 'redis',
#   'source': 'Memorystore for Redis.',
#   'launchStages': 'BETA GA',
#   'prefix': 'redis.googleapis.com',
#   'serviceIndex': 69},
#  {'name': 'router',
#   'source': 'Cloud Router.',
#   'launchStages': 'BETA GA',
#   'prefix': 'router.googleapis.com',
#   'serviceIndex': 70},
#  {'name': 'run',
#   'source': 'managed Cloud Run. (For Cloud Run for Anthos metrics, see Kubernetes metrics and Knative metrics.)',
#   'launchStages': 'BETA GA',
#   'prefix': 'run.googleapis.com',
#   'serviceIndex': 71},
#  {'name': 'serviceruntime',
#   'source': 'all Google Cloud APIs (resource type consumed_api) and to your APIs created with Cloud Endpoints (resource type api)',
#   'launchStages': '',
#   'prefix': 'serviceruntime.googleapis.com',
#   'serviceIndex': 72},
#  {'name': 'spanner',
#   'source': 'Cloud Spanner.',
#   'launchStages': 'BETA GA',
#   'prefix': 'spanner.googleapis.com',
#   'serviceIndex': 73},
#  {'name': 'storage',
#   'source': 'Cloud Storage.',
#   'launchStages': 'BETA GA',
#   'prefix': 'storage.googleapis.com',
#   'serviceIndex': 74},
#  {'name': 'storagetransfer',
#   'source': 'Storage Transfer Service.',
#   'launchStages': 'BETA',
#   'prefix': 'storagetransfer.googleapis.com',
#   'serviceIndex': 75},
#  {'name': 'tpu',
#   'source': 'Cloud TPU.',
#   'launchStages': 'BETA',
#   'prefix': 'tpu.googleapis.com',
#   'serviceIndex': 76},
#  {'name': 'trafficdirector',
#   'source': 'Traffic Director.',
#   'launchStages': 'GA',
#   'prefix': 'trafficdirector.googleapis.com',
#   'serviceIndex': 77},
#  {'name': 'transferappliance',
#   'source': 'Transfer Appliance.',
#   'launchStages': 'BETA',
#   'prefix': 'transferappliance.googleapis.com',
#   'serviceIndex': 78},
#  {'name': 'videostitcher',
#   'source': 'Video Stitcher API.',
#   'launchStages': 'BETA',
#   'prefix': 'videostitcher.googleapis.com',
#   'serviceIndex': 79},
#  {'name': 'visionai',
#   'source': 'Vision AI.',
#   'launchStages': 'BETA',
#   'prefix': 'visionai.googleapis.com',
#   'serviceIndex': 80},
#  {'name': 'vpc access',
#   'source': 'Virtual Private Cloud (VPC).',
#   'launchStages': 'BETA',
#   'prefix': 'vpcaccess.googleapis.com',
#   'serviceIndex': 81},
#  {'name': 'vpn',
#   'source': 'Cloud VPN.',
#   'launchStages': 'GA',
#   'prefix': 'vpn.googleapis.com',
#   'serviceIndex': 82},
#  {'name': 'workflows',
#   'source': 'Workflows.',
#   'launchStages': 'BETA',
#   'prefix': 'workflows.googleapis.com',
#   'serviceIndex': 83}]

# %%
metricsData = data['serviceMetrics']

# %%
metricsData[0]
# Out:
# {'metricInfo': {'name': 'smarthome_action/camerastream/first_frame_latencies',
#   'launchStatus': 'BETA',
#   'displayName': 'First frame latency'},
#  'dataInfo': {'kind': 'DELTA',
#   'type': 'DISTRIBUTION',
#   'unit': 'milliseconds',
#   'monitoredResources': 'assistant_action_project',
#   'description': 'Latency for first frame to arrive. Sampled every 60 seconds. After sampling, data is not visible for up to 180 seconds.',
#   'labels': ['device_type :\n\n              Device type, one of [CAMERA, DOORBELL]',
#    'stream_status :\n\n              The canonical code that represents the result, for example, "COMPLETED" or "FAILED".',
#    'stream_protocol :\n\n              Underlying protocol used for camerastream, for example, "webrtc" or "hls".',
#    'is_battery_powered :\n\n                (BOOL)\n\n              Whether the device is battery powered or not.']},
#  'serviceIndex': 0}

# %%
def validateMetricDatum(metricsDatum):
    metricInfo=metricsDatum['metricInfo']
    dataInfo = metricsDatum['dataInfo']
    assert len(metricInfo['name'])>0, 'invalid name'
    assert len(metricInfo['displayName'])>0, 'invalid displayName'
    assert len(dataInfo['kind'])>0, 'invalid kind'
    assert len(dataInfo['type'])>0, 'invalid type'
    # assert len(dataInfo['unit'])>0, f'invalid unit "{dataInfo.unit}"'
    # assert len(dataInfo['monitoredResources'])>0, 'invalid monitoredResources'
    assert len(dataInfo['description'])>0, 'invalid description'



validateMetricDatum(metricsData[0])

# %%
validMetricsData = []
invalidMetricsData = []
for metricsDatum in metricsData:
    try:
        validateMetricDatum(metricsDatum)
        metricsDatum['dataInfo']['labels']=list(map(lambda x: re.sub('\s+', ' ', x), metricsDatum['dataInfo']['labels']))
        validMetricsData.append(metricsDatum)
    except Exception as e:
        print(e)
        invalidMetricsData.append(metricsDatum)

# %%
(len(validMetricsDatab), len(invalidMetricsData))
# Out:
# (1487, 0)

# %%
correctedJson = {
    'service': allReorgedData,
    'serviceMetrics': validMetricsData
}

# %%
with open('validatedMetrics.json', 'w+') as jsonFile:
    json.dump(correctedJson, jsonFile)

# %%
metricsData[0]['dataInfo']['labels'][3].replace(' :\n\n              ', ': ').replace('\n\n              ', ': ')
# Out:
# 'is_battery_powered:   (BOOL)\n\n              Whether the device is battery powered or not.'

# %%
metricsData[0]['dataInfo']['labels'][3].replace('\n','', 10)
# Out:
# 'is_battery_powered :                (BOOL)              Whether the device is battery powered or not.'

# %%
re.sub('\s+', ' ', metricsData[0]['dataInfo']['labels'][3]) #.replace('\n','', -1))
# Out:
# 'is_battery_powered : (BOOL) Whether the device is battery powered or not.'
